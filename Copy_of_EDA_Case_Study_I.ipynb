# %% [markdown]
# <a href="https://colab.research.google.com/github/IchchhaRangoliya/EDA-on-different-dataset/blob/main/Copy_of_EDA_Case_Study_I.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Dataset Details**
#
# This dataset has funding information of the Indian startups from January 2015
# to August 2017.
#
# Feature Details :
# * SNo - Serial number.
# * Date - Date of funding in format DD/MM/YYYY.
# * StartupName - Name of the startup which got funded.
# * IndustryVertical - Industry to which the startup belongs.
# * SubVertical - Sub-category of the industry type.
# * CityLocation - City which the startup is based out of.
# * InvestorsName - Name of the investors involved in the funding round.
# * InvestmentType - Either Private Equity or Seed Funding.
# * AmountInUSD - Funding Amount in USD.
# * Remarks - Other information, if any.
#
# Insights -
# Find out what type of startups are getting funded in the last few years?
# Who are the important investors?
# What are the hot fields that get a lot of funding these days?

# %%
# Data Url : https://raw.githubusercontent.com/Ambatkar/Test_mnist/main/data/startup_funding.csv

# %% [markdown]
# ## Question 1
#
#
# Problem Statement :
# Check the trend of investments over the years. To check the trend, find -
# Total number of fundings done in each year.
# Plot a line graph between year and number of fundings. Take year on x-axis and number of fundings on y-axis.
# Print year-wise total number of fundings also. Print years in ascending order.
#
# Note :
# There is some error in the 'Date' feature. Make sure to handle that.
# ```
# Output Format :
#
# year1 TotalFunding1
# year2 TotalFunding2
# . . .
# ```

# %%
# Your Code here
import pandas as pd 
import numpy as np

# %%
df=pd.read_csv("https://raw.githubusercontent.com/Ambatkar/Test_mnist/main/data/startup_funding.csv")

# %%
df.head()
# Out:
#    SNo        Date   StartupName   IndustryVertical  \
# 0    0  01/08/2017      TouchKin         Technology
# 1    1  02/08/2017       Ethinos         Technology
# 2    2  02/08/2017  Leverage Edu  Consumer Internet
# 3    3  02/08/2017          Zepo  Consumer Internet
# 4    4  02/08/2017  Click2Clinic  Consumer Internet
#
#                                      SubVertical CityLocation  \
# 0                       Predictive Care Platform    Bangalore
# 1                       Digital Marketing Agency       Mumbai
# 2  Online platform for Higher Education Services    New Delhi
# 3                         DIY Ecommerce platform       Mumbai
# 4                  healthcare service aggregator    Hyderabad
#
#                                        InvestorsName  InvestmentType  \
# 0                                        Kae Capital  Private Equity
# 1                         Triton Investment Advisors  Private Equity
# ...

# %%
df.shape
# Out:
# (2372, 10)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2372 entries, 0 to 2371
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   SNo               2372 non-null   int64
#  1   Date              2372 non-null   object
#  2   StartupName       2372 non-null   object
#  3   IndustryVertical  2201 non-null   object
#  4   SubVertical       1436 non-null   object
#  5   CityLocation      2193 non-null   object
#  6   InvestorsName     2364 non-null   object
#  7   InvestmentType    2371 non-null   object
#  8   AmountInUSD       1525 non-null   object
#  9   Remarks           419 non-null    object
# dtypes: int64(1), object(9)
# memory usage: 185.4+ KB

# %%
# for i in df["Date"]:
#     print(i)

# %%
df["Date"].replace("22/01//2015","22/01/2015",inplace=True)

# %%
df["Date"].replace("12/05.2015","12/05/2015",inplace=True)
df["Date"].replace("13/04.2015","13/04/2015",inplace=True)
df["Date"].replace("15/01.2015","15/01/2015",inplace=True)

# %%
count1=0
count2=0
count3=0
for i in df["Date"]:
    a=i.split("/")[-1]
    if a=="2015":
        count1+=1
    elif a=="2016":
        count2+=1
    else:
        count3+=1
print(count1)
print(count2)
print(count3)
# Out:
# 936
# 993
# 443

# %%
936+993+443
# Out:
# 2372

# %%
df[["Date"]] = df[["Date"]].astype("datetime64")
# Out:
# C:\Users\232338\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\tools\datetimes.py:1063: UserWarning: Parsing '14/07/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\232338\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\tools\datetimes.py:1063: UserWarning: Parsing '17/07/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\232338\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\tools\datetimes.py:1063: UserWarning: Parsing '18/07/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2372 entries, 0 to 2371
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   SNo               2372 non-null   int64
#  1   Date              2372 non-null   datetime64[ns]
#  2   StartupName       2372 non-null   object
#  3   IndustryVertical  2201 non-null   object
#  4   SubVertical       1436 non-null   object
#  5   CityLocation      2193 non-null   object
#  6   InvestorsName     2364 non-null   object
#  7   InvestmentType    2371 non-null   object
#  8   AmountInUSD       1525 non-null   object
#  9   Remarks           419 non-null    object
# dtypes: datetime64[ns](1), int64(1), object(8)
# memory usage: 185.4+ KB

# %%
# for i in df["AmountInUSD"]:
#     if i==",":print(i)
# # df['AmountInUSD']=df[df['AmountInUSD'].notnull()]['AmountInUSD'].astype('int')

# %%
df["AmountInUSD"]=(df['AmountInUSD'].replace(',', '', regex=True).astype(float))

# %%
df["AmountInUSD"].mean()
# Out:
# 12031073.099016393

# %%
df["AmountInUSD"].fillna(0,inplace=True)

# %%
df["AmountInUSD"]=round(df["AmountInUSD"].astype("int"))

# %%
df["AmountInUSD"]
# Out:
# 0       1300000
# 1             0
# 2             0
# 3        500000
# 4        850000
#          ...
# 2367    4500000
# 2368     825000
# 2369    1500000
# 2370          0
# 2371     140000
# Name: AmountInUSD, Length: 2372, dtype: int32

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2372 entries, 0 to 2371
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   SNo               2372 non-null   int64
#  1   Date              2372 non-null   datetime64[ns]
#  2   StartupName       2372 non-null   object
#  3   IndustryVertical  2201 non-null   object
#  4   SubVertical       1436 non-null   object
#  5   CityLocation      2193 non-null   object
#  6   InvestorsName     2364 non-null   object
#  7   InvestmentType    2371 non-null   object
#  8   AmountInUSD       2372 non-null   int32
#  9   Remarks           419 non-null    object
# dtypes: datetime64[ns](1), int32(1), int64(1), object(7)
# memory usage: 176.2+ KB

# %%
import datetime as dt
df_2015=df[df["Date"].dt.year==2015]

# %%
df_2015
# Out:
#        SNo       Date                StartupName  \
# 1436  1436 2015-01-12               CollegeDekho
# 1437  1437 2015-01-12  Black White Orange Brands
# 1438  1438 2015-01-12                   Biteclub
# 1439  1439 2015-01-12            Patel Logistics
# 1440  1440 2015-01-12                      Wigzo
# ...    ...        ...                        ...
# 2367  2367 2015-01-29                 Printvenue
# 2368  2368 2015-01-29                   Graphene
# 2369  2369 2015-01-30             Mad Street Den
# 2370  2370 2015-01-30                  Simplotel
# 2371  2371 2015-01-31           couponmachine.in
#
#                                 IndustryVertical SubVertical CityLocation  \
# 1436       Online Education Information platform         NaN       Jaipur
# 1437                     Brand Licensing Startup         NaN       Mumbai
# 1438  Gourmet Food Discovery & Delivery platform         NaN      Gurgaon
# 1439         Transportation & Logistics Platform         NaN       Mumbai
# ...

# %%
df_2015.sum(axis=0)[4]
# Out:
# C:\Users\232338\AppData\Local\Temp/ipykernel_10928/494189890.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df_2015.sum(axis=0)[4]
# 8673022368

# %%
df_2016=df[df["Date"].dt.year==2016]

# %%
df_2016
# Out:
#        SNo       Date  StartupName   IndustryVertical  \
# 443    443 2016-01-12       SidQam         Technology
# 444    444 2016-01-12  India Lends  Consumer Internet
# 445    445 2016-01-12    Slide App  Consumer Internet
# 446    446 2016-02-12   Badiyajobs  Consumer Internet
# 447    447 2016-02-12        Streo  Consumer Internet
# ...    ...        ...          ...                ...
# 1431  1431 2016-01-29   Rare Media         Technology
# 1432  1432 2016-01-29       TinMen  Consumer Internet
# 1433  1433 2016-01-29   CodingLabs         Technology
# 1434  1434 2016-01-30  FindUrClass  Consumer Internet
# 1435  1435 2016-01-30   DesignBids  Consumer Internet
#
#                                  SubVertical CityLocation  \
# 443               Healthcare Software System        Noida
# 444    Online Instant personal Loan provider    New Delhi
# 445           Lock screen Rewards mobile app    New Delhi
# 446         Entry-Level job Seekers platform    New Delhi
# ...

# %%
df_2016.sum(axis=0)[5]
# Out:
# C:\Users\232338\AppData\Local\Temp/ipykernel_10928/2739079493.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df_2016.sum(axis=0)[5]
# 3828088608

# %%
df_2017=df[df["Date"].dt.year==2017]
df_2017
# Out:
#      SNo       Date           StartupName   IndustryVertical  \
# 0      0 2017-01-08              TouchKin         Technology
# 1      1 2017-02-08               Ethinos         Technology
# 2      2 2017-02-08          Leverage Edu  Consumer Internet
# 3      3 2017-02-08                  Zepo  Consumer Internet
# 4      4 2017-02-08          Click2Clinic  Consumer Internet
# ..   ...        ...                   ...                ...
# 438  438 2017-01-30                  FabX          eCommerce
# 439  439 2017-01-30               Maptags  Consumer Internet
# 440  440 2017-01-30           YOLO Health  Consumer Internet
# 441  441 2017-01-31    Heads Up For Tails          eCommerce
# 442  442 2017-01-31  Register My Marriage  Consumer Internet
#
#                                        SubVertical CityLocation  \
# 0                         Predictive Care Platform    Bangalore
# 1                         Digital Marketing Agency       Mumbai
# ...

# %%
df_2017.sum(axis=0)[6]
# Out:
# C:\Users\232338\AppData\Local\Temp/ipykernel_10928/2012978681.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df_2017.sum(axis=0)[6]
# 5846275500

# %%
l1=[2015,2016,2017]
l2=[12065784954,12065784954,7747185034]

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(8,8))
plt.plot(l1,l2,color="green",ls="--")

# %% [markdown]
# ## Question 2
#
# Problem Statement :
# Find out which cities are generally chosen for starting a startup.
# Find top 10 Indian cities which have most number of startups ?
# Plot a pie chart and visualise it.
# Print the city name and number of startups in that city also.
#
# Note :
# Take city name "Delhi" as "New Delhi".
# Check the case-sensitiveness of cities also. That means - at some place, instead of "Bangalore", "bangalore" is given. Take city name as "Bangalore".
# For few startups multiple locations are given, one Indian and one Foreign. Count those startups in Indian startup also. Indian city name is first.
#
# Print the city in descending order with respect to the number of startups.
# ```
# Output Format :
# city1 number1
# city2 number2
# . . .
# ```

# %%
# Your Code here

g=df.groupby('CityLocation').sum()['AmountInUSD']
g.sort_values(ascending=True)
# Out:
# CityLocation
# Agra         0.000000e+00
# Udaipur      0.000000e+00
# USA          0.000000e+00
# US           0.000000e+00
# Surat        0.000000e+00
#                  ...
# Chennai      4.111050e+08
# Gurgaon      2.067822e+09
# Mumbai       2.343694e+09
# New Delhi    2.750248e+09
# Bangalore    8.383774e+09
# Name: AmountInUSD, Length: 71, dtype: float64

# %%
df["CityLocation"].unique()
# Out:
# array(['Bangalore', 'Mumbai', 'New Delhi', 'Hyderabad', 'Ahmedabad',
#        'Gurgaon', 'Noida', 'Pune', 'Kolkata', 'bangalore', 'Trivandrum',
#        'Chennai', 'Chandigarh', 'Jaipur', 'Vadodara', 'Surat',
#        'Missourie', 'Panaji', 'Gwalior', 'Karur', 'Udupi', 'Kochi',
#        'Indore', 'Singapore', 'Goa', 'Agra', 'Bangalore/ Bangkok',
#        'Hubli', 'Delhi', 'Kerala', 'Kozhikode', 'US', 'Coimbatore',
#        'Siliguri', nan, 'USA', 'Lucknow', 'Kanpur', 'SFO / Bangalore',
#        'London', 'Seattle / Bangalore', 'Pune/Seattle', 'Pune / Dubai',
#        'Bangalore / SFO', 'Varanasi', 'Bhopal', 'New Delhi / US',
#        'Mumbai / UK', 'Jodhpur', 'Hyderabad/USA', 'Boston',
#        'Bangalore / Palo Alto', 'Mumbai / NY', 'USA/India',
#        'Goa/Hyderabad', 'Noida / Singapore', 'Belgaum', 'Pune / US',
#        'Chennai/ Singapore', 'Pune / Singapore', 'Bangalore / San Mateo',
#        'New York/ India', 'US/India', 'Gurgaon / SFO', 'Bangalore / USA',
# ...

# %%
df["CityLocation"].replace(["bangalore","Bangalore/ Bangkok","SFO / Bangalore","Seattle / Bangalore","Bangalore / SFO",
                              "Bangalore / Palo Alto","Bangalore / San Mateo","Bangalore / USA"],
                             ["Bangalore","Bangalore","SFO","Seattle","Bangalore","Bangalore","Bangalore","Bangalore"],inplace=True)

# %%
df["CityLocation"].replace(["Mumbai / UK","Mumbai / NY","Mumbai / Global"],["Mumbai","Mumbai","Mumbai"],inplace=True)

# %%
df["CityLocation"].replace(["New Delhi / US","New Delhi / California","Delhi","New Delhi/ Houston"],["New Delhi","New Delhi","New Delhi","New Delhi"],inplace=True)

# %%
df["CityLocation"].replace(["Hyderabad/USA","Goa/Hyderabad","Dallas / Hyderabad"],["Hyderabad","Hyderabad","Dallas"],inplace=True)

# %%
df["CityLocation"].replace("Gurgaon / SFO","Gurgaon",inplace=True)

# %%
df["CityLocation"].replace("Noida / Singapore","Noida",inplace=True)

# %%
df["CityLocation"].replace(['Pune/Seattle','Pune / Dubai','Pune / US','Pune / Singapore'],["Pune","Pune","Pune","Pune"],inplace=True)

# %%
df["CityLocation"].replace("Chennai/ Singapore","Chennai",inplace=True)

# %%
df["CityLocation"].replace(["USA","US/India","India / US"],["US","US","India"],inplace=True)

# %%
df["CityLocation"].replace("USA/India","US",inplace=True)
df["CityLocation"].replace("New York/ India","New York",inplace=True)

# %%
df["CityLocation"].value_counts()
# Out:
# Bangalore     635
# Mumbai        449
# New Delhi     389
# Gurgaon       241
# Pune           91
# Noida          79
# Hyderabad      78
# Chennai        67
# Ahmedabad      35
# Jaipur         25
# Kolkata        19
# Chandigarh     10
# Indore          9
# Vadodara        9
# Goa             7
# Singapore       5
# US              4
# Kanpur          4
# Coimbatore      3
# Siliguri        2
# Gwalior         2
# Bhopal          2
# Udupi           2
# Kochi           2
# Trivandrum      2
# Agra            2
# Jodhpur         1
# Boston          1
# Nagpur          1
# Belgaum         1
# New York        1
# Seattle         1
# India           1
# Udaipur         1
# Varanasi        1
# Missourie       1
# London          1
# SFO             1
# Lucknow         1
# Panaji          1
# Kozhikode       1
# Kerala          1
# Hubli           1
# Surat           1
# Karur           1
# Dallas          1
# Name: CityLocation, dtype: int64

# %%
plt.figure(figsize=(10,10))
plt.pie(df["CityLocation"].value_counts()[0:10],autopct="%1.02f")
plt.legend(df["CityLocation"])
plt.show()

# %% [markdown]
# ## Question 3
#
#
# Problem Statement :
# Find out if cities play any role in receiving funding.
# Find top 10 Indian cities with most amount of fundings received. Find out percentage of funding each city has got (among top 10 Indian cities only).
# Print the city and percentage with 2 decimal place after rounding off.
#
# Note:
# Take city name "Delhi" as "New Delhi".
# Check the case-sensitiveness of cities also. That means - at some place, instead of "Bangalore", "bangalore" is given. Take city name as "Bangalore".
# For few startups multiple locations are given, one Indian and one Foreign. Count those startups in Indian startup also. Indian city name is first.
#
# Print the city in descending order with respect to the percentage of funding.
#
# ```
# Output Format :
# city1 percent1
# city2 percent2
# city3 percent3
# . . .
# . . .
# . . .
# ```

# %%
g=df.groupby('CityLocation').sum()['AmountInUSD']
g.sort_values(ascending=False)
# Out:
# CityLocation
# Bangalore     8.422974e+09
# New Delhi     2.818248e+09
# Mumbai        2.354934e+09
# Gurgaon       2.069022e+09
# Chennai       4.111050e+08
# Pune          3.666530e+08
# Hyderabad     1.953620e+08
# Noida         1.706380e+08
# Ahmedabad     9.818600e+07
# Jaipur        3.556000e+07
# India         3.000000e+07
# Chandigarh    2.610000e+07
# US            1.960000e+07
# Kolkata       1.386500e+07
# Udupi         1.200000e+07
# Vadodara      6.040000e+06
# Singapore     3.850000e+06
# Boston        3.000000e+06
# New York      2.950000e+06
# SFO           2.700000e+06
# Goa           2.380000e+06
# Bhopal        1.900000e+06
# Indore        1.672000e+06
# Coimbatore    1.650000e+06
# Dallas        1.000000e+06
# Lucknow       1.000000e+06
# Gwalior       9.000000e+05
# Panaji        8.250000e+05
# Belgaum       5.000000e+05
# Missourie     3.500000e+05
# Kanpur        2.200000e+05
# Jodhpur       1.600000e+05
# Trivandrum    1.000000e+05
# ...

# %%
df.groupby("CityLocation").sum()["AmountInUSD"][0:10].plot.pie(y="AmountInUSD",autopct="%1.02f%%",figsize=(10,10))
# Out:
# <AxesSubplot:ylabel='AmountInUSD'>

# %% [markdown]
# ## Question 4
#
#
# Problem Statement :
# There are 4 different type of investments. Find out percentage of amount funded for each investment type.
# Plot a pie chart to visualise.
# Print the investment type and percentage of amount funded with 2 decimal places after rounding off.
#
# Note :
# Correct spelling of investment types are - "Private Equity", "Seed Funding", "Debt Funding", and "Crowd Funding". Keep an eye for any spelling mistake. You can find this by printing unique values from this column.
# Print the investment type in descending order with respect to the percentage of the amount funded.
#
# ```
# Output Format :
# investmentType1 percent1
# investmentType2 percent2
# investmentType3 percent3
# . . .
# ```

# %%
# Your Code here

df["InvestmentType"].unique()
# Out:
# array(['Private Equity', 'Seed Funding', 'Debt Funding', nan,
#        'SeedFunding', 'PrivateEquity', 'Crowd funding', 'Crowd Funding'],
#       dtype=object)

# %%
df["InvestmentType"].replace(["PrivateEquity","SeedFunding","Crowd funding"],["Private Equity","Seed Funding","Crowd Funding"],inplace=True)

# %%
b=df.groupby("InvestmentType")
b.first().sort_values(by="AmountInUSD",ascending=False)[0:5]
# Out:
#                  SNo       Date   StartupName   IndustryVertical  \
# InvestmentType
# Debt Funding      68 2017-12-06   LendingKart  Consumer Internet
# Private Equity     0 2017-01-08      TouchKin         Technology
# Crowd Funding   2328 2015-07-01      Nurturey               None
# Seed Funding       2 2017-02-08  Leverage Edu  Consumer Internet
#
#                                                   SubVertical CityLocation  \
# InvestmentType
# Debt Funding                          Online Lending platform    Ahmedabad
# Private Equity                       Predictive Care Platform    Bangalore
# Crowd Funding                                            None         None
# Seed Funding    Online platform for Higher Education Services    New Delhi
#
#                                                     InvestorsName  \
# InvestmentType
# Debt Funding                                             Yes Bank
# Private Equity                                        Kae Capital
# ...

# %%
df.groupby("InvestmentType").sum().plot.pie(y="AmountInUSD",autopct="%1.02f%%",figsize=(5,5))
# Out:
# <AxesSubplot:ylabel='AmountInUSD'>

# %%
f=df.groupby('InvestmentType').sum()['AmountInUSD']
f
# Out:
# InvestmentType
# Crowd Funding     1.557680e+05
# Debt Funding      7.800000e+06
# Private Equity    1.800708e+10
# Seed Funding      3.323457e+08
# Name: AmountInUSD, dtype: float64

# %%
plt.pie(f,autopct="%1.02f%%")
# Out:
# ([<matplotlib.patches.Wedge at 0x183f6cedf60>,
# ...
#  [Text(1.0999999996087355, 2.9339086372947604e-05, ''),
#   Text(1.0999989389883453, 0.0015278169113626045, ''),
#   Text(-1.0983035592070438, 0.061067928023962124, ''),
#   Text(1.09821934367324, -0.06256415253097043, '')],
#  [Text(0.5999999997865829, 1.6003138021607783e-05, '0.00%'),
#   Text(0.5999994212663702, 0.0008333546789250569, '0.04%'),
#   Text(-0.5990746686583874, 0.03330977892216115, '98.15%'),
#   Text(0.5990287329126762, -0.034125901380529323, '1.81%')])

# %% [markdown]
# ## Question 5
#
# Problem Statement :
# Which type of companies got more easily funding. To answer this question, find -
# Top 5 industries and percentage of the total amount funded to that industry. (among top 5 only)
#
# Print the industry name and percentage of the amount funded with 2 decimal place after rounding off.
#
# Note :
# Ecommerce is the right word in IndustryVertical, so correct it.
# Print the industry in descending order with respect to the percentage of the amount funded.
# ```
# Output Format :
# industry1 percent1
# industry2 percent2
# industry3 percent3
# . . .
# ```

# %%
# Your Code here
df["IndustryVertical"].replace(["eCommerce","ECommerce"],"Ecommerce",inplace=True)
df["IndustryVertical"].value_counts()
# Out:
# Consumer Internet                                   772
# Technology                                          313
# Ecommerce                                           227
# Healthcare                                           30
# Logistics                                            24
#                                                    ...
# Virtual Reality activity based learning platform      1
# Online Grocery Store                                  1
# Investment management platform                        1
# Industrial Toons Marketplace                          1
# Online Travel Marketplace                             1
# Name: IndustryVertical, Length: 741, dtype: int64

# %%
a=df.groupby("IndustryVertical")
a.first().sort_values(by="AmountInUSD",ascending=False)[0:5]
# Out:
#                                      SNo       Date   StartupName SubVertical  \
# IndustryVertical
# Online Marketplace                  1976 2015-07-28  Flipkart.com        None
# E-Commerce & M-Commerce platform    1787 2015-09-29         Paytm        None
# Ecommerce Marketplace               1798 2015-01-08      Snapdeal        None
# Car Aggregator & Retail Mobile App  1572 2015-11-18           Ola        None
# Cab Aggregator                      2148 2015-08-04       Olacabs        None
#
#                                    CityLocation  \
# IndustryVertical
# Online Marketplace                    Bangalore
# E-Commerce & M-Commerce platform      New Delhi
# Ecommerce Marketplace                 New Delhi
# Car Aggregator & Retail Mobile App    Bangalore
# Cab Aggregator                        Bangalore
#
#                                                                         InvestorsName  \
# IndustryVertical
# ...

# %%
onlinemarket=(700000000/np.sum(df["AmountInUSD"]))*100
round(onlinemarket,2)
# Out:
# 3.82

# %%
ecommerce=(680000000/np.sum(df["AmountInUSD"]))*100
round(ecommerce,2)
# Out:
# 3.71

# %%
ecommercemarket=(500000000/np.sum(df["AmountInUSD"]))*100
round(ecommercemarket,2)
# Out:
# 2.73

# %%
caragg=(500000000/np.sum(df["AmountInUSD"]))*100
round(caragg,2)
# Out:
# 2.73

# %%
cabagg=(400000000/np.sum(df["AmountInUSD"]))*100
round(cabagg,2)
# Out:
# 2.18

# %%
tp10fund=df.groupby('IndustryVertical')['AmountInUSD'].sum().sort_values(ascending=False)
tp10fund.head(10)
# Out:
# IndustryVertical
# Ecommerce                             4.279110e+09
# Consumer Internet                     3.797089e+09
# Technology                            1.103594e+09
# Online Marketplace                    7.000000e+08
# E-Commerce & M-Commerce platform      6.800000e+08
# Car Aggregator & Retail Mobile App    5.000000e+08
# Ecommerce Marketplace                 5.000000e+08
# Cab Aggregator                        4.000000e+08
# Cab rental Mobile app                 2.250000e+08
# Logistics                             1.806450e+08
# Name: AmountInUSD, dtype: float64

# %%
df["IndustryVertical"].unique().shape
# Out:
# (742,)

# %% [markdown]
# ## Question 6
#
#
# Problem Statement :
# Find top 5 startups with most amount of total funding.
# Print the startup name in descending order with respect to amount of funding.
#
# Note:
# Ola, Flipkart, Oyo, Paytm are important startups, so correct their names. There are many errors in startup names, ignore correcting all, just handle important ones.
#
# ```
# Output Format :
# startup1
# startup2
# startup3
# . . .
# ```

# %%
# Your Code here
df_ola=df[df["StartupName"]=="Ola"]
df_paytm=df[df["StartupName"]=="Paytm"]
df_flipkart=df[df["StartupName"]=="Flipkart"]
df_oyo=df[df["StartupName"]=="Oyo"]

# %%
df_ola.sum(axis=0)
# Out:
# C:\Users\232338\AppData\Local\Temp/ipykernel_10928/4210440780.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df_ola.sum(axis=0)
# SNo                                                              2019
# StartupName                                              OlaOlaOlaOla
# IndustryVertical    Consumer InternetConsumer InternetConsumer Int...
# CityLocation                     BangaloreBangaloreBangaloreBangalore
# InvestorsName       Tekne Capital Management LLCFalcon Edge Capita...
# InvestmentType      Private EquityPrivate EquityPrivate EquityPriv...
# AmountInUSD                                                 984500000
# dtype: object

# %%
df_paytm.sum(axis=0)
# Out:
# C:\Users\232338\AppData\Local\Temp/ipykernel_10928/2200135610.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df_paytm.sum(axis=0)
# SNo                                                            7260
# StartupName                               PaytmPaytmPaytmPaytmPaytm
# InvestorsName     SoftBank GroupMediaTek Inc.Alibaba Group, Ant ...
# InvestmentType    Private EquityPrivate EquityPrivate EquityPriv...
# AmountInUSD                                              2140000000
# dtype: object

# %%
df_flipkart.sum(axis=0)
# Out:
# C:\Users\232338\AppData\Local\Temp/ipykernel_10928/3468428327.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df_flipkart.sum(axis=0)
# SNo                                                              2772
# StartupName                          FlipkartFlipkartFlipkartFlipkart
# IndustryVertical        EcommerceEcommerceEcommerceeCommerce platform
# CityLocation                     BangaloreBangaloreBangaloreBangalore
# InvestorsName       NaspersMicrosoft, eBay, Tencent HoldingsBennet...
# InvestmentType      Private EquityPrivate EquityPrivate EquityPriv...
# AmountInUSD                                                1559700000
# dtype: object

# %%
df_oyo.sum(axis=0)
# Out:
# C:\Users\232338\AppData\Local\Temp/ipykernel_10928/476086214.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df_oyo.sum(axis=0)
# SNo                                                              1088
# StartupName                                                       Oyo
# IndustryVertical                                    Consumer Internet
# SubVertical                Online Branded Budget Room Booking Service
# CityLocation                                                New Delhi
# InvestorsName       Softbank, Sequoia Capital, Lightspeed Venture ...
# InvestmentType                                         Private Equity
# AmountInUSD                                                 100000000
# Remarks                                                             0
# dtype: object

# %%
d={"ola":1511531073,"paytm":2364062146,"flipkart":2304150000,"oyo":612000000}
df_new=pd.Series(d)
df_new.sort_values(ascending=True)
# Out:
# oyo          612000000
# ola         1511531073
# flipkart    2304150000
# paytm       2364062146
# dtype: int64

# %%
df["StartupName"].replace(["Ola Cabs","Olacabs"],["Ola","Ola"],inplace=True)
# df["StartupName"].replace("LendingKart","Flipkart",inplace=True)
df["StartupName"].replace("Flipkart.com","Flipkart",inplace=True)
df["StartupName"].replace("Oyo Rooms","Oyo",inplace=True)
df["StartupName"].replace("OyoRooms","Oyo",inplace=True)
df["StartupName"].replace("Oyorooms","Oyo",inplace=True)
df["StartupName"].replace("Oyo Rooms","Oyo",inplace=True)
df["StartupName"].replace("Paytm Marketplace","Paytm",inplace=True)
df["StartupName"].value_counts()[0:10]
# Out:
# Ola          9
# Swiggy       7
# Paytm        6
# UrbanClap    6
# NoBroker     5
# Jugnoo       5
# Medinfi      5
# Oyo          5
# Flipkart     5
# TinyStep     4
# Name: StartupName, dtype: int64

# %%
tp10fund=df.groupby('StartupName')['AmountInUSD'].sum().sort_values(ascending=False)
tp10fund.head(10)
# Out:
# StartupName
# Paytm         2.340000e+09
# Flipkart      2.259700e+09
# Ola           1.899500e+09
# Snapdeal      7.000000e+08
# Oyo           6.120000e+08
# Quikr         2.300000e+08
# Delhivery     2.150000e+08
# Foodpanda     2.100000e+08
# BigBasket     2.070000e+08
# MakeMyTrip    1.800000e+08
# Name: AmountInUSD, dtype: float64

# %% [markdown]
# ## Question 7
#
# Problem Statement :
# Find the top 5 startups who received the most number of funding rounds. That means, startups which got fundings maximum number of times.
# Print the startup name in descending order with respect to the number of funding round as integer value.
#
# Note:
# Ola, Flipkart, Oyo, Paytm are important startups, so correct their names. There are many errors in startup names, ignore correcting all, just handle important ones.
#
# ```
# Output Format :
# startup1 number1
# startup2 number2
# startup3 number3
# . . .
# ```

# %%
# Your Code here

df["StartupName"].value_counts()[0:10]
# Out:
# Ola          9
# Swiggy       7
# Paytm        6
# UrbanClap    6
# NoBroker     5
# Jugnoo       5
# Medinfi      5
# Oyo          5
# Flipkart     5
# TinyStep     4
# Name: StartupName, dtype: int64

# %%
count=0
for i in df["StartupName"]:
    print(i)
    if "Oyo" in i:
        count+=1
# Out:
# TouchKin
# Ethinos
# Leverage Edu
# Zepo
# Click2Clinic
# Billion Loans
# Ecolibriumenergy
# Droom
# Jumbotail
# Moglix
# Timesaverz
# Minjar
# MyCity4kids
# Clip App
# Upwardly.in
# Autorox.co
# Fabogo
# Flickstree
# Design Cafe
# Innoviti
# VDeliver
# Bottr.me
# Arcatron
# QwikSpec
# Chumbak
# Increff
# Vayana
# MObiquest
# Ambee
# Ideal Insurance
# Hypernova Interactive
# Rentomojo
# AirCTO
# Playablo
# Trupay
# Brick2Wall
# FableStreet
# Monsoon Fintech
# MonkeyBox
# Noticeboard
# Byju’s
# Creator’s Gurukul
# Fab Hotels
# ThinkerBell
# 1mg
# Jhakaas
# BigStylist
# Gympik.com
# Tripeur
# RentOnGo
# Goomo
# MaxMyWealth
# Spinny
# Healthbuds
# Ftcash
# BHIVE Workspace
# wayForward
# GyanDhan
# Hungry Foal
# ZipLoan
# GrowFitter
# Stratfit
# Multiplier Solutions
# ABI Health
# Stockal
# Guidoo
# eSahai.in
# Loanmeet
# LendingKart
# Boxx.ai
# PeeSafe.in
# Vista Rooms
# CoverFox
# HyperTrack
# Goodera
# Digit
# Ola
# Vanitycask
# MrNeeds
# MoneyTap
# Goodbox
# Fincash
# PortDesk
# ...

# %%
for i in df["StartupName"]:
    if "Paytm" in i:
        print(i)
# Out:
# Paytm
# Paytm
# Paytm
# Paytm
# Paytm
# Paytm

# %% [markdown]
# ## Question 8
#
# **Problem Statement :**
# Find the Investors who have invested maximum number of times.
# Print the investor name and number of times invested as integer value.
#
# **Note:**
# In startup, multiple investors might have invested. So consider each investor for that startup.
# Ignore the undisclosed investors.
#
# ```
# Output Format :
# investorname number
# ```

# %%
# Your Code here
df["InvestorsName"].value_counts()
# Out:
# Undisclosed Investors                                                                                            33
# Undisclosed investors                                                                                            27
# Ratan Tata                                                                                                       24
# Indian Angel Network                                                                                             24
# Kalaari Capital                                                                                                  16
#                                                                                                                  ..
# Anand Chandrasekaran, Ananth Narayanan, Mekin Maheshwari, Ravi Garikipati, Divyesh Shah, Swastika Company Ltd     1
# Powerhouse Ventures, M&S Partners                                                                                 1
# ...

# %%
df["InvestorsName"].unique()
# Out:
# array(['Kae Capital', 'Triton Investment Advisors',
#        'Kashyap Deorah, Anand Sankeshwar, Deepak Jain, Sadashiva NT, Arjun Mehta, Satish Kaul, Anindya Ghose',
#        ..., 'KARSEMVEN Fund', 'Exfinity Fund, GrowX Ventures.',
#        'UK based Group of Angel Investors'], dtype=object)
